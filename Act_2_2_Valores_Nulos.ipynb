# %% [markdown]
# <a href="https://colab.research.google.com/github/LuisPablo19/Valores-Nulos/blob/main/Act_2_2_Valores_Nulos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Actividad 2.2 (Valores Nulos)**
#
# Amairany Rodríguez Huerta| A01702927
#
# Luis Pablo Padilla Barbosa | A00572040
#
# Renata Emilia Chávez Martínez| A01351716

# %% [markdown]
# Limpiaremos las bases de datos del socio formador para poderlo utilizar en nuestro reto a futuro.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import files

# %% [markdown]
# ##Datos de Facturación

# %%
#files.upload()

# %%
Facturacion= pd.read_excel("Datos de Facturación.xlsx")
Facturacion.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10895 entries, 0 to 10894
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CVE_DOC        10895 non-null  object
#  1   CVE_CLPV       10895 non-null  object
#  2   STATUS         10895 non-null  object
#  3   CVE_VEND       10847 non-null  float64
#  4   FECHAELAB      10895 non-null  datetime64[ns]
#  5   FECHA_DOC      10895 non-null  datetime64[ns]
#  6   FECHA_ENT      10893 non-null  object
#  7   FECHA_VEN      10895 non-null  datetime64[ns]
#  8   FECHA_CANCELA  358 non-null    datetime64[ns]
#  9   CAN_TOT        10895 non-null  float64
#  10  DES_TOT        10895 non-null  float64
#  11  DES_FIN        10895 non-null  int64
# dtypes: datetime64[ns](4), float64(3), int64(1), object(4)
# memory usage: 1021.5+ KB

# %%
valores_nulos = Facturacion.isnull().sum()
valores_nulos
# Out:
# CVE_DOC              0
# CVE_CLPV             0
# STATUS               0
# CVE_VEND            48
# FECHAELAB            0
# FECHA_DOC            0
# FECHA_ENT            2
# FECHA_VEN            0
# FECHA_CANCELA    10537
# CAN_TOT              0
# DES_TOT              0
# DES_FIN              0
# dtype: int64

# %% [markdown]
# ###CVE_VEND

# %%
Facturacion['CVE_VEND'].unique()
# Out:
# array([ 1.,  2.,  3.,  5.,  4., nan,  6.,  9., 10.,  7., 11., 12.])

# %%
Facturacion['CVE_VEND']=Facturacion['CVE_VEND'].fillna(8)

# %%
valores_nulos = Facturacion.isnull().sum()
valores_nulos
# Out:
# CVE_DOC              0
# CVE_CLPV             0
# STATUS               0
# CVE_VEND             0
# FECHAELAB            0
# FECHA_DOC            0
# FECHA_ENT            2
# FECHA_VEN            0
# FECHA_CANCELA    10537
# CAN_TOT              0
# DES_TOT              0
# DES_FIN              0
# dtype: int64

# %% [markdown]
# ###FECHA_ENT

# %%
indices = Facturacion[Facturacion["FECHA_ENT"].isnull()==True].index
valores = Facturacion.loc[indices, ["FECHA_DOC"]].values
Facturacion.loc[indices, ["FECHA_ENT"]] = valores

# %%
valores_nulos = Facturacion.isnull().sum()
valores_nulos
# Out:
# CVE_DOC              0
# CVE_CLPV             0
# STATUS               0
# CVE_VEND             0
# FECHAELAB            0
# FECHA_DOC            0
# FECHA_ENT            0
# FECHA_VEN            0
# FECHA_CANCELA    10537
# CAN_TOT              0
# DES_TOT              0
# DES_FIN              0
# dtype: int64

# %% [markdown]
# ###FECHA_CANCELA

# %%
Facturacion["FECHA_CANCELA"]=Facturacion["FECHA_CANCELA"].fillna("2050-01-01 00:00:00")

# %%
valores_nulos = Facturacion.isnull().sum()
valores_nulos
# Out:
# CVE_DOC          0
# CVE_CLPV         0
# STATUS           0
# CVE_VEND         0
# FECHAELAB        0
# FECHA_DOC        0
# FECHA_ENT        0
# FECHA_VEN        0
# FECHA_CANCELA    0
# CAN_TOT          0
# DES_TOT          0
# DES_FIN          0
# dtype: int64

# %%
#Convertir en CSV
Facturacion.to_csv("Datos de Facturación_SIN NULOS.csv")

# %%
from google.colab import files  
files.download("Datos de Facturación_SIN NULOS.csv")

# %% [markdown]
# ##Detalle de precios y productos fabricados

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_excel("Detalle precios y productos fabricados 2022.xlsx")
df
# Out:
#      CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# 0     F37034 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 1     F37036 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 2     F37041 2022-01-05   DIEGO ARMANDO LEON DURAN
# 3     F37042 2022-01-05   DIEGO ARMANDO LEON DURAN
# 4     F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# ...      ...        ...                        ...
# 1421  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1422  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1423  F39835 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1424  F39837 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1425  F39838 2022-12-23         AARON NUÑO CORDOVA
#
#                     NOMBRE_CLIENTE  CANT       CVE_ART  \
# 0               PÚBLICO EN GENERAL     1      TUE00244
# 1     JUAN ANTONIO RESENDIZ UGALDE     1      TUA00028
# 2        ANA BARBARA CRUZ PALACIOS     7        TP0007
# 3             OMAR RODRIGUEZ GOMEZ     1        TP0001
# 4               PÚBLICO EN GENERAL     2       BP00242
# ...

# %%
# identificamos columnas con valores nulos
valores_nulos=df.isnull().sum()
valores_nulos
# Out:
# CVE_DOC                      0
# FECHA_DOC                    0
# NOMBRE_VENDEDOR              2
# NOMBRE_CLIENTE               0
# CANT                         0
# CVE_ART                      0
# DESCR                        0
# PRECIO_UNITARIO              0
# COSTO_UNITARIO               0
# COSTO_UNITARIO_CALCULADO     0
# SUBTOTAL_PARTIDA             0
# COSTO_TOTAL_CALCULADO        0
# MARGEN_UNITARIO_CALCULADO    0
# MARGEN_TOTAL_CALCULADO       0
# dtype: int64

# %%
# nulos totales en el archivo
valores_nulos=df.isnull().sum().sum()
valores_nulos
# Out:
# 2

# %%
# copia del archivo
data=df.copy()

# %%
data["NOMBRE_VENDEDOR"] =data["NOMBRE_VENDEDOR"].fillna("NO EXISTE")

# %%
# ya no hay nulos en la columna
valores_nulos=data.isnull().sum()
valores_nulos
# Out:
# CVE_DOC                      0
# FECHA_DOC                    0
# NOMBRE_VENDEDOR              0
# NOMBRE_CLIENTE               0
# CANT                         0
# CVE_ART                      0
# DESCR                        0
# PRECIO_UNITARIO              0
# COSTO_UNITARIO               0
# COSTO_UNITARIO_CALCULADO     0
# SUBTOTAL_PARTIDA             0
# COSTO_TOTAL_CALCULADO        0
# MARGEN_UNITARIO_CALCULADO    0
# MARGEN_TOTAL_CALCULADO       0
# dtype: int64

# %%
#Convertir DataFrame a CSV
data.to_csv("Detalle precios y productos fabricados 2022_SIN NULOS.csv")

# %%
from google.colab import files  
files.download("Detalle precios y productos fabricados 2022_SIN NULOS.csv")

# %% [markdown]
# ## Gastos y costos 20-23

# %%
#Importamos librerías requeridas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Cargar archivo csv desde equipo
#from google.colab import files
#files.upload()

# %%
#Carga desde un archivo de excel
df= pd.read_excel("Gastos y costos 20-23.xlsx", skiprows=5)
df
# Out:
#           FECHA                   FOLIO                                  UUID  \
# 0    2020-01-01                   39408  BD20F436-72CC-4BE2-AD37-5999D71AA391
# 1    2020-01-01  0001010100750847116902  85AEAC2E-6395-44A0-9CB9-754D06893375
# 2    2020-01-01  0001010100752163714102  BD0DFE85-D776-41CB-9C5C-4FA7923E687A
# 3    2020-01-01                    3663  EF4504D6-830D-415C-AF03-80CF54C5E28E
# 4    2020-01-01                    2849  EC2F4AA4-BA64-4E2E-A5B7-4EBBE042D6D3
# ...         ...                     ...                                   ...
# 3337 2020-12-01                  125834  80BCB1D8-673F-495B-9C2A-4AC9F9CB38E5
# 3338 2020-12-01                   37652  D4C7C1FB-03A7-4046-A2BD-03EBE7DA861E
# 3339 2020-12-01                     160  FFCEE7D4-1F38-4D44-BE02-EB042DAACEE7
# 3340 2020-12-01                  634875  8DFF4F01-2F8B-4085-B116-05A314108B02
# 3341 2020-12-01                 1044477  F18225D6-4024-4F03-A15A-D18917386D59
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3342 entries, 0 to 3341
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   FECHA        3342 non-null   datetime64[ns]
#  1   FOLIO        3153 non-null   object
#  2   UUID         3342 non-null   object
#  3   RFC          3342 non-null   object
#  4   PROVEEDOR    3342 non-null   object
#  5   TIPO GASTO   3342 non-null   object
#  6   GASTO        840 non-null    object
#  7   DESCRIPCION  3342 non-null   object
#  8   TC           2951 non-null   float64
#  9   IMPORTE      3308 non-null   float64
#  10  IVA          3074 non-null   float64
#  11  RET ISR      3342 non-null   float64
#  12  RET IVA      3342 non-null   float64
#  13  TOTAL MX     3342 non-null   float64
#  14  TOTAL SAT    3342 non-null   float64
#  15  TIPO         3341 non-null   object
#  16  STATUS       3342 non-null   object
#  17  POLIZA       21 non-null     object
# ...

# %%
valores_nulos=df.isnull().sum()
valores_nulos
# Out:
# FECHA             0
# FOLIO           189
# UUID              0
# RFC               0
# PROVEEDOR         0
# TIPO GASTO        0
# GASTO          2502
# DESCRIPCION       0
# TC              391
# IMPORTE          34
# IVA             268
# RET ISR           0
# RET IVA           0
# TOTAL MX          0
# TOTAL SAT         0
# TIPO              1
# STATUS            0
# POLIZA         3321
# Columna1          0
# dtype: int64

# %% [markdown]
# Considerando las columnas de POLIZA así como las columna de GASTO vemos que los valores que faltan son más de la mitad de los datos ingresados en la base de datos. Es mejor simplemente dar de baja las columnas de la base de datos considerando que no se tiene la informacíon necesaria para hacer una sustitución como una media o una mediana.

# %%
df=df.drop(['POLIZA','GASTO'], axis=1)
df
# Out:
#           FECHA                   FOLIO                                  UUID  \
# 0    2020-01-01                   39408  BD20F436-72CC-4BE2-AD37-5999D71AA391
# 1    2020-01-01  0001010100750847116902  85AEAC2E-6395-44A0-9CB9-754D06893375
# 2    2020-01-01  0001010100752163714102  BD0DFE85-D776-41CB-9C5C-4FA7923E687A
# 3    2020-01-01                    3663  EF4504D6-830D-415C-AF03-80CF54C5E28E
# 4    2020-01-01                    2849  EC2F4AA4-BA64-4E2E-A5B7-4EBBE042D6D3
# ...         ...                     ...                                   ...
# 3337 2020-12-01                  125834  80BCB1D8-673F-495B-9C2A-4AC9F9CB38E5
# 3338 2020-12-01                   37652  D4C7C1FB-03A7-4046-A2BD-03EBE7DA861E
# 3339 2020-12-01                     160  FFCEE7D4-1F38-4D44-BE02-EB042DAACEE7
# 3340 2020-12-01                  634875  8DFF4F01-2F8B-4085-B116-05A314108B02
# 3341 2020-12-01                 1044477  F18225D6-4024-4F03-A15A-D18917386D59
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3342 entries, 0 to 3341
# Data columns (total 17 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   FECHA        3342 non-null   datetime64[ns]
#  1   FOLIO        3153 non-null   object
#  2   UUID         3342 non-null   object
#  3   RFC          3342 non-null   object
#  4   PROVEEDOR    3342 non-null   object
#  5   TIPO GASTO   3342 non-null   object
#  6   DESCRIPCION  3342 non-null   object
#  7   TC           2951 non-null   float64
#  8   IMPORTE      3308 non-null   float64
#  9   IVA          3074 non-null   float64
#  10  RET ISR      3342 non-null   float64
#  11  RET IVA      3342 non-null   float64
#  12  TOTAL MX     3342 non-null   float64
#  13  TOTAL SAT    3342 non-null   float64
#  14  TIPO         3341 non-null   object
#  15  STATUS       3342 non-null   object
#  16  Columna1     3342 non-null   float64
# dtypes: datetime64[ns](1), float64(8), object(8)
# ...

# %%
valores_nulos1=df.isnull().sum()
valores_nulos1
# Out:
# FECHA            0
# FOLIO          189
# UUID             0
# RFC              0
# PROVEEDOR        0
# TIPO GASTO       0
# DESCRIPCION      0
# TC             391
# IMPORTE         34
# IVA            268
# RET ISR          0
# RET IVA          0
# TOTAL MX         0
# TOTAL SAT        0
# TIPO             1
# STATUS           0
# Columna1         0
# dtype: int64

# %% [markdown]
# Como podemos ver tenemos ahora columnas con datos NA menores a un 25% por los que se hará una una sustitución por datos anteriores, medias o medianas.

# %%
df1=df.copy()
df1
# Out:
#           FECHA                   FOLIO                                  UUID  \
# 0    2020-01-01                   39408  BD20F436-72CC-4BE2-AD37-5999D71AA391
# 1    2020-01-01  0001010100750847116902  85AEAC2E-6395-44A0-9CB9-754D06893375
# 2    2020-01-01  0001010100752163714102  BD0DFE85-D776-41CB-9C5C-4FA7923E687A
# 3    2020-01-01                    3663  EF4504D6-830D-415C-AF03-80CF54C5E28E
# 4    2020-01-01                    2849  EC2F4AA4-BA64-4E2E-A5B7-4EBBE042D6D3
# ...         ...                     ...                                   ...
# 3337 2020-12-01                  125834  80BCB1D8-673F-495B-9C2A-4AC9F9CB38E5
# 3338 2020-12-01                   37652  D4C7C1FB-03A7-4046-A2BD-03EBE7DA861E
# 3339 2020-12-01                     160  FFCEE7D4-1F38-4D44-BE02-EB042DAACEE7
# 3340 2020-12-01                  634875  8DFF4F01-2F8B-4085-B116-05A314108B02
# 3341 2020-12-01                 1044477  F18225D6-4024-4F03-A15A-D18917386D59
#
# ...

# %%
df1['TIPO']=df1['TIPO'].fillna(method='bfill')
valores_nulos2=df1.isnull().sum()
valores_nulos2
# Out:
# FECHA            0
# FOLIO          189
# UUID             0
# RFC              0
# PROVEEDOR        0
# TIPO GASTO       0
# DESCRIPCION      0
# TC             391
# IMPORTE         34
# IVA            268
# RET ISR          0
# RET IVA          0
# TOTAL MX         0
# TOTAL SAT        0
# TIPO             0
# STATUS           0
# Columna1         0
# dtype: int64

# %%
df1['IVA']=df1['IVA'].fillna(round(df1['TOTAL SAT']*0.1379,1))
valores_nulos3=df1.isnull().sum()
valores_nulos3
# Out:
# FECHA            0
# FOLIO          189
# UUID             0
# RFC              0
# PROVEEDOR        0
# TIPO GASTO       0
# DESCRIPCION      0
# TC             391
# IMPORTE         34
# IVA              0
# RET ISR          0
# RET IVA          0
# TOTAL MX         0
# TOTAL SAT        0
# TIPO             0
# STATUS           0
# Columna1         0
# dtype: int64

# %%
df1['IMPORTE']=df1['IMPORTE'].fillna(round(df['IMPORTE'].median(),1))
valores_nulos4=df1.isnull().sum()
valores_nulos4
# Out:
# FECHA            0
# FOLIO          189
# UUID             0
# RFC              0
# PROVEEDOR        0
# TIPO GASTO       0
# DESCRIPCION      0
# TC             391
# IMPORTE          0
# IVA              0
# RET ISR          0
# RET IVA          0
# TOTAL MX         0
# TOTAL SAT        0
# TIPO             0
# STATUS           0
# Columna1         0
# dtype: int64

# %%
df1['TC']=df1['TC'].fillna(1)
valores_nulos5=df1.isnull().sum()
valores_nulos5
# Out:
# FECHA            0
# FOLIO          189
# UUID             0
# RFC              0
# PROVEEDOR        0
# TIPO GASTO       0
# DESCRIPCION      0
# TC               0
# IMPORTE          0
# IVA              0
# RET ISR          0
# RET IVA          0
# TOTAL MX         0
# TOTAL SAT        0
# TIPO             0
# STATUS           0
# Columna1         0
# dtype: int64

# %%
df1['FOLIO']=df1['FOLIO'].fillna(000000)
valaores_nulos6=df1.isnull().sum()
valaores_nulos6
# Out:
# FECHA          0
# FOLIO          0
# UUID           0
# RFC            0
# PROVEEDOR      0
# TIPO GASTO     0
# DESCRIPCION    0
# TC             0
# IMPORTE        0
# IVA            0
# RET ISR        0
# RET IVA        0
# TOTAL MX       0
# TOTAL SAT      0
# TIPO           0
# STATUS         0
# Columna1       0
# dtype: int64

# %%
#Convertir DataFrame a CSV
df1.to_excel('Gastos y costos 20-23 (SN).xlsx')

# %%
#Descargar el CSV
from google.colab import files

files.download('Gastos y costos 20-23 (SN).xlsx')
